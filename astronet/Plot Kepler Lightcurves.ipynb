# %%
from light_curve_util import kepler_io
import matplotlib.pyplot as plt
import numpy as np
import os
import matplotlib
# %matplotlib inline
font = {        'size'   : 20}
matplotlib.rc('font', **font)

# %%
KEPLER_DATA_DIR = "/home/idies/workspace/kepler/data/kepler/data"

KEPLER_ID = 11442793  # Kepler-90.

# %%
# Read the light curve.
file_names = kepler_io.kepler_filenames(KEPLER_DATA_DIR, KEPLER_ID)
print(file_names)
assert file_names, "Failed to find .fits files in {}".format(KEPLER_DATA_DIR)
all_time, all_flux = kepler_io.read_kepler_light_curve(file_names)
print("Read light curve with {} segments".format(len(all_time)))
# Out:
# ['/home/idies/workspace/kepler/data/kepler/data/0114/011442793/kplr011442793-2009166043257_llc.fits', '/home/idies/workspace/kepler/data/kepler/data/0114/011442793/kplr011442793-2009259160929_llc.fits', '/home/idies/workspace/kepler/data/kepler/data/0114/011442793/kplr011442793-2009350155506_llc.fits', '/home/idies/workspace/kepler/data/kepler/data/0114/011442793/kplr011442793-2010009091648_llc.fits', '/home/idies/workspace/kepler/data/kepler/data/0114/011442793/kplr011442793-2010174085026_llc.fits', '/home/idies/workspace/kepler/data/kepler/data/0114/011442793/kplr011442793-2010265121752_llc.fits', '/home/idies/workspace/kepler/data/kepler/data/0114/011442793/kplr011442793-2010355172524_llc.fits', '/home/idies/workspace/kepler/data/kepler/data/0114/011442793/kplr011442793-2011177032512_llc.fits', '/home/idies/workspace/kepler/data/kepler/data/0114/011442793/kplr011442793-2011271113734_llc.fits', '/home/idies/workspace/kepler/data/kepler/data/0114/011442793/kplr011442793-2012004120508_llc.fits', '/home/idies/workspace/kepler/data/kepler/data/0114/011442793/kplr011442793-2012179063303_llc.fits', '/home/idies/workspace/kepler/data/kepler/data/0114/011442793/kplr011442793-2012277125453_llc.fits', '/home/idies/workspace/kepler/data/kepler/data/0114/011442793/kplr011442793-2013011073258_llc.fits', '/home/idies/workspace/kepler/data/kepler/data/0114/011442793/kplr011442793-2013131215648_llc.fits']
# Read light curve with 14 segments

# %%
# Plot the fourth segment.
plt.plot(all_time[3], all_flux[3], ".")

# %%
# Plot all light curve segments. We first divide by the median flux in each
# segment, because the segments are on different scales.
for f in all_flux:
  f /= np.median(f)
plt.figure(figsize=(12,6))
plt.plot(np.concatenate(all_time), np.concatenate(all_flux), ".")

# %%
# !sh evaluate_model.sh
# Out:
# /home/idies/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:tensorflow:Using config: {'_model_dir': '/home/idies/workspace/Storage/tdo/planets_ml/checkpoints/', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7ff9c5c57208>, '_task_type': 'worker', '_task_id': 0, '_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Starting evaluation on checkpoint /home/idies/workspace/Storage/tdo/planets_ml/checkpoints/model.ckpt-10000
# INFO:tensorflow:Building input pipeline from 1 files matching patterns: ['/home/idies/workspace/Storage/tdo/planets_ml/tfrecord/test*']
# INFO:tensorflow:Starting evaluation at 2018-05-11-20:21:21
# 2018-05-11 20:21:22.156484: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2
# INFO:tensorflow:Restoring parameters from /home/idies/workspace/Storage/tdo/planets_ml/checkpoints/model.ckpt-10000
# INFO:tensorflow:Finished evaluation at 2018-05-11-20:21:29
# INFO:tensorflow:Saving dict for global step 10000: accuracy/accuracy = 0.96442187, accuracy/num_correct = 1518.0, auc = 0.9901406, confusion_matrix/false_negatives = 10.0, confusion_matrix/false_positives = 46.0, confusion_matrix/true_negatives = 1168.0, confusion_matrix/true_positives = 350.0, global_step = 10000, loss = 0.10564246, losses/weighted_cross_entropy = 0.10609667, num_examples = 1574.0

# %%
# !sh predict_example.sh
# Out:
# /home/idies/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:tensorflow:Using config: {'_model_dir': '/home/idies/workspace/Storage/tdo/planets_ml/checkpoints/', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f9f57284b38>, '_task_type': 'worker', '_task_id': 0, '_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# 2018-05-11 20:50:22.024110: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2
# INFO:tensorflow:Restoring parameters from /home/idies/workspace/Storage/tdo/planets_ml/checkpoints/model.ckpt-10000
# Prediction: 1.8745757e-05

# %%
# !sh predict_example-false-positive.sh
# Out:
# /home/idies/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:tensorflow:Using config: {'_model_dir': '/home/idies/workspace/Storage/tdo/planets_ml/checkpoints/', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f8f805379e8>, '_task_type': 'worker', '_task_id': 0, '_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# 2018-06-01 20:20:33.857177: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2
# INFO:tensorflow:Restoring parameters from /home/idies/workspace/Storage/tdo/planets_ml/checkpoints/model.ckpt-10000
# Prediction: 0.71320504

# %%
# !sh predict_example-11820830.sh
# Out:
# /home/idies/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:tensorflow:Using config: {'_model_dir': '/home/idies/workspace/Storage/tdo/planets_ml/checkpoints/', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f2a680569e8>, '_task_type': 'worker', '_task_id': 0, '_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# 2018-06-01 21:19:35.434009: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2
# INFO:tensorflow:Restoring parameters from /home/idies/workspace/Storage/tdo/planets_ml/checkpoints/model.ckpt-10000
# Prediction: 0.17465751

# %%
# !sh predict_example-10666592.sh
# Out:
# /home/idies/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:tensorflow:Using config: {'_model_dir': '/home/idies/workspace/Storage/tdo/planets_ml/checkpoints/', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f11e61179e8>, '_task_type': 'worker', '_task_id': 0, '_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# 2018-06-01 21:27:31.394981: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2
# INFO:tensorflow:Restoring parameters from /home/idies/workspace/Storage/tdo/planets_ml/checkpoints/model.ckpt-10000
# Prediction: 0.0061428733
